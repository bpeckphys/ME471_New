# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import subprocess
from mpl_toolkits.mplot3d.axes3d import Axes3D
from matplotlib import cm

# %%
# %%bash
# mpirun -n 1 Final_Project -n 4 --itermax 1000000 --tol 1e-10 > Final_Project_4.csv

# %%
# %%bash
# mpirun -n 1 Final_Project -n 8 --itermax 1000000 --tol 1e-10 > Final_Project_8.csv

# %%
# %%bash
# mpirun -n 1 Final_Project -n 16 --itermax 1000000 --tol 1e-10 > Final_Project_16.csv

# %%
# %%bash
# mpirun -n 1 Final_Project -n 32 --itermax 1000000 --tol 1e-10 > Final_Project_32.csv

# %%
A = np.genfromtxt('Final_Project_16.csv', delimiter=',')
print("iterations: %d" % A[-3])
print("residual: %g" % A[-2])
print("error: %g" % A[-1])
A = A[:-3]
z = int(np.sqrt(len(A)))
A = A.reshape((z,z))
print("nodes: %d" % (z*z))
fig = plt.figure()
ax = fig.gca(projection='3d')
X = np.arange(0, 1+1/z, 1/(z-1))
Y = np.arange(0, 1+1/z, 1/(z-1))
X, Y = np.meshgrid(X, Y)
Z = np.exp(X*Y)
surf = ax.plot_surface(X, Y, A, cmap=cm.coolwarm,
                       linewidth=0, antialiased=False)
ax.plot_wireframe(X, Y, Z, rstride=1, cstride=1)
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
#ax.view_init(30, 15)
# Out:
# iterations: 1022
# residual: 9.95821e-11
# error: 1.2023e-05
# nodes: 289
# Text(0.5,0,'Z')

# %%
data = {}
columns = ['iterations', 'residual', 'error']
df = pd.DataFrame(columns=columns)
for n in [4,8,16,32]:    
    A = np.genfromtxt('Final_Project_' + str(n) +'.csv', delimiter=',')
    iterations = A[-3]
    residual = A[-2]
    error = A[-1]
    A = A[:-3]
    
    data_row = {'iterations': iterations, 'residual': residual, 'error':error}
    df = df.append(pd.Series(data=data_row, name=str(n)))
print(df)
# Out:
#     iterations      residual     error
# 4         66.0  7.636736e-11  0.000156
# 8        268.0  9.941692e-11  0.000046
# 16      1022.0  9.958212e-11  0.000012
# 32      3820.0  9.987633e-11  0.000003

# %%
data = {}
columns = ['N', 'iterations', 'residual', 'error']
df = pd.DataFrame(columns=columns)
for n in [4,8,16,32]:    
    A = np.genfromtxt('Final_Project_' + str(n) + '.csv', delimiter=',')
    iterations = A[-3]
    residual = A[-2]
    error = A[-1]
    A = A[:-3]
    
    data_row = {'N': (n), 'iterations': iterations, 'residual': residual, 'error':error}
    df = df.append(pd.Series(data=data_row, name=str(n)))
print(df)
df.plot(x='N', y='error', loglog=True)
# Out:
#        N  iterations      residual     error
# 4    4.0        66.0  7.636736e-11  0.000156
# 8    8.0       268.0  9.941692e-11  0.000046
# 16  16.0      1022.0  9.958212e-11  0.000012
# 32  32.0      3820.0  9.987633e-11  0.000003
