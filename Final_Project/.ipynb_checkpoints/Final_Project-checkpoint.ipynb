# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import subprocess
from mpl_toolkits.mplot3d.axes3d import Axes3D
from matplotlib import cm

# %%
# %%bash
# mpirun -n 1 Final_Project -n 16 --itermax 1000000 --tol 1e-10 > Final_Project.csv

# %%
A = np.genfromtxt('Final_Project.csv', delimiter=',')
print("iterations: %d" % A[-3])
print("residual: %g" % A[-2])
print("error: %g" % A[-1])
A = A[:-3]
z = int(np.sqrt(len(A)))
A = A.reshape((z,z))
print("nodes: %d" % (z*z))
#x = np.linspace(0,1,z)
#y = np.linspace(0,1,z)
#plt.plot(x,y, A,'r.')
#plt.plot(x,y, np.exp(x*y), 'b-')
fig = plt.figure()
ax = fig.gca(projection='3d')
X = np.arange(0, 1+1/z, 1/(z-1))
Y = np.arange(0, 1+1/z, 1/(z-1))
X, Y = np.meshgrid(X, Y)
Z = np.exp(X*Y)
surf = ax.plot_surface(X, Y, A, cmap=cm.coolwarm,
                       linewidth=0, antialiased=False)
ax.plot_wireframe(X, Y, Z, rstride=1, cstride=1)
# Out:
# iterations: 1022
# residual: 9.96452e-11
# error: 1.2023e-05
# nodes: 289
